# %% [markdown]
# # Plots

# %% [markdown]
# ## Control Charts

# %%
import tprstats
import pandas as pd

df = pd.read_excel("../data/Theta_data.xlsx", engine='openpyxl').dropna()
tprstats.control_chart(mu = 50, sig = 0.3, n = 25, alpha = 0.05, data = df.XBAR)

# %%
# controlChartBinary(Defects_data$d_rate,.06,85,.05)
df_defects = pd.read_excel("../data/Defects_data.xlsx", engine='openpyxl').dropna()
tprstats.control_chart_binary(p = 0.06, n = 85, alpha = .05, data = df_defects.d_rate)

# %%
df = pd.read_excel("../data/Theta_new.xlsx", engine='openpyxl').dropna()
tprstats.control_chart(mu = 25, sig = 0.2, n = 25, alpha = 0.05, data = df.XBAR3)
