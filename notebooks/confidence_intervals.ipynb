# %%
import tprstats
import statsmodels.formula.api as smf
import statsmodels.api as sm
import formulaic 
import pandas as pd
# tire_data = pd.read_excel('../data/Tire_Pricing.xlsx', engine='openpyxl')
# coffee_data = pd.read_excel('../data/Coffee_Data.xlsx', engine='openpyxl')
# diamonds_211 = pd.read_excel('../data/Diamonds_211.xlsx', engine='openpyxl')
# diamonds_e_100= pd.read_excel('../data/Diamond_E_100.xlsx', engine='openpyxl')
# diamonds_e_100['Cut'] = diamonds_e_100['Cut'].astype("category")
# diamonds_e_100 = diamonds_e_100.astype({'Cut': 'category', 'Clarity': 'category', 'Color': 'category', 'Price': 'float'})
# solar_data = pd.read_excel('../data/Solar_Data.xlsx', engine='openpyxl')
# solar_new_prospects = pd.read_excel('../data/Solar_New_Prospects.xlsx', engine='openpyxl')
diamonds_17 = pd.read_excel('../data/Diamonds_17.xlsx', engine='openpyxl')

# %%
OurReg = tprstats.model("cs", "Price ~ Carat", diamonds_17)

# %%
OurReg.summary()
# Out:
# /workspaces/tprstats-python/.pixi/envs/default/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=17 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.560
# No. Observations:                  17   F-statistic:                     12.32
# Covariance Type:                  HC1   Prob (F-statistic):            0.00316
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    268.7373    927.890      0.290      0.776   -1709.013    2246.488
# Carat       4305.4059   1226.850      3.509      0.003    1690.438    6920.374
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
smf.ols("Price ~ Carat", diamonds_17).fit(cov_type="HC1").summary()
# Out:
# /workspaces/tprstats-python/.pixi/envs/default/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=17 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     12.32
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):            0.00316
# Time:                        19:52:19   Log-Likelihood:                -109.76
# No. Observations:                  17   AIC:                             223.5
# Df Residuals:                      15   BIC:                             225.2
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    268.7373    927.890      0.290      0.772   -1549.894    2087.368
# Carat       4305.4059   1226.850      3.509      0.000    1900.825    6709.987
# ==============================================================================
# Omnibus:                        0.661   Durbin-Watson:                   1.701
# Prob(Omnibus):                  0.719   Jarque-Bera (JB):                0.609
# Skew:                           0.388   Prob(JB):                        0.737
# Kurtosis:                       2.492   Cond. No.                         36.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
y, X = formulaic.model_matrix("Price ~ Carat", diamonds_17)
model = sm.OLS(y, X)
result = model.fit(cov_type="HC1", use_t=True)
result.summary()
# Out:
# /workspaces/tprstats-python/.pixi/envs/default/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=17 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     12.32
# Date:                Tue, 11 Feb 2025   Prob (F-statistic):            0.00316
# Time:                        19:52:26   Log-Likelihood:                -109.76
# No. Observations:                  17   AIC:                             223.5
# Df Residuals:                      15   BIC:                             225.2
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    268.7373    927.890      0.290      0.776   -1709.013    2246.488
# Carat       4305.4059   1226.850      3.509      0.003    1690.438    6920.374
# ==============================================================================
# Omnibus:                        0.661   Durbin-Watson:                   1.701
# Prob(Omnibus):                  0.719   Jarque-Bera (JB):                0.609
# Skew:                           0.388   Prob(JB):                        0.737
# Kurtosis:                       2.492   Cond. No.                         36.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """
